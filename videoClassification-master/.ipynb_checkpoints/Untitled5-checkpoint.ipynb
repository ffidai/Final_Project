# %%
import numpy as np

# %%
# USAGE

# python predict_video.py --model model/activity_gpu.model --label-bin model/lb.pickle --input example_clips/cyclone_movie.mp4 --output output/cyclon_movie_output.avi --size 10

# import the necessary packages
from tensorflow.keras.models import load_model
from collections import deque
import numpy as np
import argparse
import pickle
import cv2
from twilio.rest import Client
import csv
import pandas as pd
import numpy as np
import datetime


# load the trained model and label binarizer from disk
print("[INFO] loading model and label binarizer...")
model = load_model("model")
lb = pickle.loads(open("model/lb.pickle", "rb").read())

# initialize the image mean for mean subtraction along with the
# predictions queue
mean = np.array([123.68, 116.779, 103.939][::1], dtype="float32")
Q = deque(maxlen=30)

# initialize the video stream, pointer to output video file, and
# frame dimensions
vs = cv2.VideoCapture("example_clips/LeftTest.MOV")
writer = None
(W, H) = (None, None)
prelabel = ''
ok = 'Normal'
fi_label = []
framecount = 0

frames = []
shots = []
player = []

playerNo = round(np.random.rand()*100)

forehandCount = 0
backhandCount = 0
# Out:
# [INFO] loading model and label binarizer...

# %%
while True:
	# read the next frame from the file
	(grabbed, frame) = vs.read()

	# if the frame was not grabbed, then we have reached the end
	# of the stream
	if not grabbed:
		break

	# if the frame dimensions are empty, grab them
	if W is None or H is None:
		(H, W) = frame.shape[:2]
	framecount = framecount+1
	# clone the output frame, then convert it from BGR to RGB
	# ordering, resize the frame to a fixed 224x224, and then
	# perform mean subtraction
#	cv2.imshow("Output", frame)
	output = frame.copy()
	frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
	frame = cv2.resize(frame, (224, 224)).astype("float32")
	frame -= mean
#	cv2.imshow("Output", frame)

	# make predictions on the frame and then update the predictions
	# queue
	preds = model.predict(np.expand_dims(frame, axis=0))[0]
#	print('Preds = :', preds)
	
#	total = (preds[0]+ preds[1]+preds[2] + preds[3]+ preds[4]+preds[5])
#	maximum = max(preds)
#	rest = total - maximum
    
#	diff = (.8*maximum) - (.1*rest)
#	print('Difference of prob ', diff)
#	th = 100
#	if diff > .60:
#		th = diff
#	print('Old threshold = ', th)
    
    
	prediction = preds.argmax(axis=0)
	Q.append(preds)

	# perform prediction averaging over the current history of
	# previous predictions
	results = np.array(Q).mean(axis=0)
	print('Results = ', results)
	maxprob = np.max(results)
	print('Maximun Probability = ', maxprob)
	i = np.argmax(results)
	print("i = ", i)
	label = lb[i]

	rest = 1 - maxprob
    
	diff = (maxprob) - (rest)
	#print('Difference of prob ', diff)
	th = 100
	if diff > .80:
		th = diff
      
	frames.append(framecount)
	player.append(playerNo)
	shots.append(i)
        
        
	print(label, ':' , prelabel)   
	if framecount > 10:
		if label != prelabel:
			if (i==0):
				backhandCount += 1
			else:
				forehandCount += 1
    
	text = "{} - {:.2f}%".format((label), maxprob * 100)
	#text = ""
	text = text + "Backhand count : " + str(backhandCount) + "\n"
	text = text + "Forehand count : " + str(forehandCount)
	cv2.putText(output, text, (35, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 5)


	prelabel = label    



	# check if the video writer is None
	if writer is None:
		# initialize our video writer
		fourcc = cv2.VideoWriter_fourcc(*"MJPG")
		#writer = cv2.VideoWriter(args["output"] + datetime.datetime.now().strftime('%b-%d-%Y_%H%M'), fourcc, 30, (W, H), True)
		writer = cv2.VideoWriter( "output/"+ datetime.datetime.now().strftime('%b_%d_%Y_%H%M'+'.MOV'), fourcc, 30, (W, H), True)
		

# 	# write the output frame to disk
	writer.write(frame)

# 	# show the output image
	cv2.imshow("Output", frame)
	key = cv2.waitKey(1) & 0xFF

	# if the `q` key was pressed, break from the loop
	if key == ord("q"):
		break
print('Frame count', framecount)
#print('Count label', fi_label)
# release the file pointers
print("[INFO] cleaning up...")
writer.release()
vs.release()
# Out:
# Results =  [0.09255692 0.9074431 ]
# Maximun Probability =  0.9074431
# i =  1
# backhand :
# Results =  [0.07977547 0.92022455]
# Maximun Probability =  0.92022455
# i =  1
# backhand : backhand
# Results =  [0.07445917 0.92554086]
# Maximun Probability =  0.92554086
# i =  1
# backhand : backhand
# Results =  [0.07006411 0.9299359 ]
# Maximun Probability =  0.9299359
# i =  1
# backhand : backhand
# Results =  [0.06895012 0.93104994]
# Maximun Probability =  0.93104994
# i =  1
# backhand : backhand
# Results =  [0.07037273 0.92962724]
# Maximun Probability =  0.92962724
# i =  1
# backhand : backhand
# Results =  [0.06839741 0.9316026 ]
# Maximun Probability =  0.9316026
# i =  1
# backhand : backhand
# Results =  [0.06797925 0.9320208 ]
# Maximun Probability =  0.9320208
# i =  1
# backhand : backhand
# Results =  [0.06767399 0.932326  ]
# Maximun Probability =  0.932326
# i =  1
# backhand : backhand
# Results =  [0.07077987 0.9292201 ]
# Maximun Probability =  0.9292201
# i =  1
# backhand : backhand
# Results =  [0.08055332 0.9194467 ]
# Maximun Probability =  0.9194467
# i =  1
# backhand : backhand
# Results =  [0.09489387 0.9051061 ]
# Maximun Probability =  0.9051061
# i =  1
# backhand : backhand
# Results =  [0.09900126 0.9009988 ]
# Maximun Probability =  0.9009988
# i =  1
# backhand : backhand
# Results =  [0.10202003 0.89798003]
# Maximun Probability =  0.89798003
# i =  1
# backhand : backhand
# Results =  [0.10262283 0.8973772 ]
# Maximun Probability =  0.8973772
# i =  1
# backhand : backhand
# Results =  [0.10371502 0.896285  ]
# Maximun Probability =  0.896285
# i =  1
# backhand : backhand
# Results =  [0.10813013 0.8918699 ]
# Maximun Probability =  0.8918699
# i =  1
# backhand : backhand
# Results =  [0.11153057 0.88846946]
# Maximun Probability =  0.88846946
# i =  1
# backhand : backhand
# Results =  [0.11206372 0.88793623]
# Maximun Probability =  0.88793623
# i =  1
# backhand : backhand
# Results =  [0.11580171 0.8841983 ]
# Maximun Probability =  0.8841983
# i =  1
# backhand : backhand
# Results =  [0.11412087 0.88587916]
# Maximun Probability =  0.88587916
# i =  1
# backhand : backhand
# Results =  [0.1128988 0.8871012]
# Maximun Probability =  0.8871012
# i =  1
# backhand : backhand
# Results =  [0.11495534 0.8850447 ]
# Maximun Probability =  0.8850447
# i =  1
# backhand : backhand
# Results =  [0.11696569 0.8830343 ]
# Maximun Probability =  0.8830343
# i =  1
# backhand : backhand
# Results =  [0.11552902 0.884471  ]
# Maximun Probability =  0.884471
# i =  1
# backhand : backhand
# Results =  [0.11407184 0.88592815]
# Maximun Probability =  0.88592815
# i =  1
# backhand : backhand
# Results =  [0.11257482 0.8874252 ]
# Maximun Probability =  0.8874252
# i =  1
# backhand : backhand
# Results =  [0.10994846 0.8900515 ]
# Maximun Probability =  0.8900515
# i =  1
# backhand : backhand
# Results =  [0.10723127 0.89276874]
# Maximun Probability =  0.89276874
# i =  1
# backhand : backhand
# Results =  [0.10532319 0.8946768 ]
# Maximun Probability =  0.8946768
# i =  1
# backhand : backhand
# Results =  [0.10305081 0.8969492 ]
# Maximun Probability =  0.8969492
# i =  1
# backhand : backhand
# Results =  [0.10286421 0.8971358 ]
# Maximun Probability =  0.8971358
# i =  1
# backhand : backhand
# Results =  [0.10228539 0.8977146 ]
# Maximun Probability =  0.8977146
# i =  1
# backhand : backhand
# Results =  [0.10102258 0.89897734]
# Maximun Probability =  0.89897734
# i =  1
# backhand : backhand
# Results =  [0.10094938 0.8990506 ]
# Maximun Probability =  0.8990506
# i =  1
# backhand : backhand
# Results =  [0.09995575 0.9000443 ]
# Maximun Probability =  0.9000443
# i =  1
# backhand : backhand
# Results =  [0.10094943 0.89905065]
# Maximun Probability =  0.89905065
# i =  1
# backhand : backhand
# Results =  [0.10128871 0.8987114 ]
# Maximun Probability =  0.8987114
# i =  1
# backhand : backhand
# Results =  [0.10264336 0.89735675]
# Maximun Probability =  0.89735675
# i =  1
# backhand : backhand
# Results =  [0.10208438 0.89791566]
# Maximun Probability =  0.89791566
# i =  1
# backhand : backhand
# Results =  [0.10165652 0.8983435 ]
# Maximun Probability =  0.8983435
# i =  1
# backhand : backhand
# Results =  [0.09797931 0.9020209 ]
# Maximun Probability =  0.9020209
# i =  1
# backhand : backhand
# Results =  [0.09651259 0.90348756]
# Maximun Probability =  0.90348756
# i =  1
# backhand : backhand
# Results =  [0.09668401 0.90331614]
# Maximun Probability =  0.90331614
# i =  1
# backhand : backhand
# Results =  [0.09733535 0.9026648 ]
# Maximun Probability =  0.9026648
# i =  1
# backhand : backhand
# Results =  [0.09799475 0.9020054 ]
# Maximun Probability =  0.9020054
# i =  1
# backhand : backhand
# Results =  [0.09723961 0.90276057]
# Maximun Probability =  0.90276057
# i =  1
# backhand : backhand
# Results =  [0.09767883 0.9023214 ]
# Maximun Probability =  0.9023214
# i =  1
# backhand : backhand
# Results =  [0.10865978 0.8913404 ]
# Maximun Probability =  0.8913404
# i =  1
# backhand : backhand
# Results =  [0.11398753 0.8860126 ]
# Maximun Probability =  0.8860126
# i =  1
# backhand : backhand
# Results =  [0.12161127 0.8783888 ]
# Maximun Probability =  0.8783888
# i =  1
# backhand : backhand
# Results =  [0.12723358 0.8727665 ]
# Maximun Probability =  0.8727665
# i =  1
# backhand : backhand
# Results =  [0.13509639 0.86490375]
# Maximun Probability =  0.86490375
# i =  1
# backhand : backhand
# Results =  [0.13836384 0.8616362 ]
# Maximun Probability =  0.8616362
# i =  1
# backhand : backhand
# Results =  [0.14412673 0.8558733 ]
# Maximun Probability =  0.8558733
# i =  1
# backhand : backhand
# Results =  [0.1577734 0.8422267]
# Maximun Probability =  0.8422267
# i =  1
# backhand : backhand
# Results =  [0.16992603 0.83007395]
# Maximun Probability =  0.83007395
# i =  1
# backhand : backhand
# Results =  [0.18858038 0.81141967]
# Maximun Probability =  0.81141967
# i =  1
# backhand : backhand
# Results =  [0.20197202 0.798028  ]
# Maximun Probability =  0.798028
# i =  1
# backhand : backhand
# Results =  [0.21754847 0.7824515 ]
# Maximun Probability =  0.7824515
# i =  1
# backhand : backhand
# Results =  [0.23384911 0.7661508 ]
# Maximun Probability =  0.7661508
# i =  1
# backhand : backhand
# Results =  [0.24215809 0.7578419 ]
# Maximun Probability =  0.7578419
# i =  1
# backhand : backhand
# Results =  [0.2512883  0.74871165]
# Maximun Probability =  0.74871165
# i =  1
# backhand : backhand
# Results =  [0.2672539 0.732746 ]
# Maximun Probability =  0.732746
# i =  1
# backhand : backhand
# Results =  [0.28845593 0.7115441 ]
# Maximun Probability =  0.7115441
# i =  1
# backhand : backhand
# Results =  [0.30660105 0.6933989 ]
# Maximun Probability =  0.6933989
# i =  1
# backhand : backhand
# Results =  [0.3162695 0.6837304]
# Maximun Probability =  0.6837304
# i =  1
# backhand : backhand
# Results =  [0.32968065 0.6703194 ]
# Maximun Probability =  0.6703194
# i =  1
# backhand : backhand
# Results =  [0.33945495 0.6605452 ]
# Maximun Probability =  0.6605452
# i =  1
# backhand : backhand
# Results =  [0.35337004 0.64663005]
# Maximun Probability =  0.64663005
# i =  1
# backhand : backhand
# Results =  [0.3676127 0.6323874]
# Maximun Probability =  0.6323874
# i =  1
# backhand : backhand
# Results =  [0.3803555 0.6196446]
# Maximun Probability =  0.6196446
# i =  1
# backhand : backhand
# Results =  [0.38944104 0.61055905]
# Maximun Probability =  0.61055905
# i =  1
# backhand : backhand
# Results =  [0.394649  0.6053511]
# Maximun Probability =  0.6053511
# i =  1
# backhand : backhand
# Results =  [0.3976763 0.6023238]
# Maximun Probability =  0.6023238
# i =  1
# backhand : backhand
# Results =  [0.40220517 0.5977948 ]
# Maximun Probability =  0.5977948
# i =  1
# backhand : backhand
# Results =  [0.40574837 0.59425163]
# Maximun Probability =  0.59425163
# i =  1
# backhand : backhand
# Results =  [0.4044174  0.59558266]
# Maximun Probability =  0.59558266
# i =  1
# backhand : backhand
# Results =  [0.39418146 0.60581857]
# Maximun Probability =  0.60581857
# i =  1
# backhand : backhand
# Results =  [0.3936365  0.60636353]
# Maximun Probability =  0.60636353
# i =  1
# backhand : backhand
# Results =  [0.3940439  0.60595614]
# Maximun Probability =  0.60595614
# i =  1
# backhand : backhand
# Results =  [0.3965643 0.6034357]
# Maximun Probability =  0.6034357
# i =  1
# backhand : backhand
# Results =  [0.3897191 0.6102809]
# Maximun Probability =  0.6102809
# i =  1
# backhand : backhand
# Results =  [0.38786677 0.61213326]
# Maximun Probability =  0.61213326
# i =  1
# backhand : backhand
# Results =  [0.390361 0.609639]
# Maximun Probability =  0.609639
# i =  1
# backhand : backhand
# Results =  [0.38319388 0.6168061 ]
# Maximun Probability =  0.6168061
# i =  1
# backhand : backhand
# Results =  [0.375593 0.624407]
# Maximun Probability =  0.624407
# i =  1
# backhand : backhand
# Results =  [0.3621689  0.63783103]
# Maximun Probability =  0.63783103
# i =  1
# backhand : backhand
# Results =  [0.3562321 0.6437678]
# Maximun Probability =  0.6437678
# i =  1
# backhand : backhand
# Results =  [0.3507203  0.64927965]
# Maximun Probability =  0.64927965
# i =  1
# backhand : backhand
# Results =  [0.34018385 0.659816  ]
# Maximun Probability =  0.659816
# i =  1
# backhand : backhand
# Results =  [0.33640873 0.66359115]
# Maximun Probability =  0.66359115
# i =  1
# backhand : backhand
# Results =  [0.33006254 0.6699373 ]
# Maximun Probability =  0.6699373
# i =  1
# backhand : backhand
# Results =  [0.32046384 0.6795361 ]
# Maximun Probability =  0.6795361
# i =  1
# backhand : backhand
# Results =  [0.3017063 0.6982936]
# Maximun Probability =  0.6982936
# i =  1
# backhand : backhand
# Results =  [0.2864052  0.71359473]
# Maximun Probability =  0.71359473
# i =  1
# backhand : backhand
# Results =  [0.28094923 0.71905077]
# Maximun Probability =  0.71905077
# i =  1
# backhand : backhand
# Results =  [0.2696373 0.7303627]
# Maximun Probability =  0.7303627
# i =  1
# backhand : backhand
# Results =  [0.25885522 0.74114484]
# Maximun Probability =  0.74114484
# i =  1
# backhand : backhand
# Results =  [0.24668151 0.7533186 ]
# Maximun Probability =  0.7533186
# i =  1
# backhand : backhand
# Results =  [0.23245178 0.7675483 ]
# Maximun Probability =  0.7675483
# i =  1
# backhand : backhand
# Results =  [0.22168602 0.77831405]
# Maximun Probability =  0.77831405
# i =  1
# backhand : backhand
# Results =  [0.2167497 0.7832504]
# Maximun Probability =  0.7832504
# i =  1
# backhand : backhand
# Results =  [0.21402611 0.78597397]
# Maximun Probability =  0.78597397
# i =  1
# backhand : backhand
# Results =  [0.2136856 0.7863144]
# Maximun Probability =  0.7863144
# i =  1
# backhand : backhand
# Results =  [0.21503882 0.7849611 ]
# Maximun Probability =  0.7849611
# i =  1
# backhand : backhand
# Results =  [0.21191376 0.7880862 ]
# Maximun Probability =  0.7880862
# i =  1
# backhand : backhand
# Results =  [0.21011262 0.78988737]
# Maximun Probability =  0.78988737
# i =  1
# backhand : backhand
# Results =  [0.2089507  0.79104924]
# Maximun Probability =  0.79104924
# i =  1
# backhand : backhand
# Results =  [0.20318861 0.7968113 ]
# Maximun Probability =  0.7968113
# i =  1
# backhand : backhand
# Results =  [0.19789237 0.8021075 ]
# Maximun Probability =  0.8021075
# i =  1
# backhand : backhand
# Results =  [0.19313964 0.8068602 ]
# Maximun Probability =  0.8068602
# i =  1
# backhand : backhand
# Results =  [0.19875233 0.8012476 ]
# Maximun Probability =  0.8012476
# i =  1
# backhand : backhand
# Results =  [0.20218347 0.7978164 ]
# Maximun Probability =  0.7978164
# i =  1
# backhand : backhand
# Results =  [0.20750155 0.7924984 ]
# Maximun Probability =  0.7924984
# i =  1
# backhand : backhand
# Results =  [0.21640234 0.7835976 ]
# Maximun Probability =  0.7835976
# i =  1
# backhand : backhand
# Results =  [0.23008326 0.76991665]
# Maximun Probability =  0.76991665
# i =  1
# backhand : backhand
# Results =  [0.24317928 0.7568207 ]
# Maximun Probability =  0.7568207
# i =  1
# backhand : backhand
# Results =  [0.24659008 0.7534099 ]
# Maximun Probability =  0.7534099
# i =  1
# backhand : backhand
# Results =  [0.24756455 0.75243545]
# Maximun Probability =  0.75243545
# i =  1
# backhand : backhand
# Results =  [0.25416985 0.7458301 ]
# Maximun Probability =  0.7458301
# i =  1
# backhand : backhand
# Results =  [0.2635168  0.73648316]
# Maximun Probability =  0.73648316
# i =  1
# backhand : backhand
# Results =  [0.27746493 0.72253495]
# Maximun Probability =  0.72253495
# i =  1
# backhand : backhand
# Results =  [0.28804561 0.71195424]
# Maximun Probability =  0.71195424
# i =  1
# backhand : backhand
# Results =  [0.30075243 0.69924754]
# Maximun Probability =  0.69924754
# i =  1
# backhand : backhand
# Results =  [0.313769   0.68623096]
# Maximun Probability =  0.68623096
# i =  1
# backhand : backhand
# Results =  [0.330704 0.669296]
# Maximun Probability =  0.669296
# i =  1
# backhand : backhand
# Results =  [0.34619376 0.65380627]
# Maximun Probability =  0.65380627
# i =  1
# backhand : backhand
# Results =  [0.36793664 0.6320633 ]
# Maximun Probability =  0.6320633
# i =  1
# backhand : backhand
# Results =  [0.38322696 0.61677307]
# Maximun Probability =  0.61677307
# i =  1
# backhand : backhand
